# %% [markdown]
# #EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Dry_Bean.csv")

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
df['Class'].unique()
# Out:
# array(['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON'],
#       dtype=object)

# %%
df['Class'] = df['Class'].map({"SEKER":0,"BARBUNYA":1,'BOMBAY':2, 'CALI':3, 'HOROZ':4, 'SIRA':5, 'DERMASON':6})

# %%
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
df.corr()
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966722         0.931834         0.951602
# Perimeter        0.966722   1.000000         0.977338         0.913179
# MajorAxisLength  0.931834   0.977338         1.000000         0.826052
# MinorAxisLength  0.951602   0.913179         0.826052         1.000000
# AspectRation     0.241735   0.385276         0.550335        -0.009161
# Eccentricity     0.267481   0.391066         0.541972         0.019574
# ConvexArea       0.999939   0.967689         0.932607         0.951339
# EquivDiameter    0.984968   0.991380         0.961733         0.948539
# Extent           0.054345  -0.021160        -0.078062         0.145957
# Solidity        -0.196585  -0.303970        -0.284302        -0.155831
# roundness       -0.357530  -0.547647        -0.596358        -0.210344
# Compactness     -0.268067  -0.406857        -0.568377        -0.015066
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
plt.pie(df['Class'].value_counts(),labels=['SEKER','BARBUNYA','BOMBAY','CALI','HOROZ','SIRA','DERMASON'])
plt.show()
##count chart/plot

# %% [markdown]
# Classification problem

# %% [markdown]
# no null values

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
df.columns
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4', 'Class'],
#       dtype='object')

# %%
df['new'] = df['Area']+ df['Perimeter']+ df['MajorAxisLength']+ df['MinorAxisLength']

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class  \
# ...

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Class", y ="Area", data = df)
# Out:
# <Axes: xlabel='Class', ylabel='Area'>

# %%
matplotlib.rcParams['figure.figsize']=(12,6)
plt.boxplot(df["Area"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d274f6808b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d274f680d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d274f680610>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d274f6812a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d274f681540>],
#  'means': []}

# %% [markdown]
# these are not outliers, but the 2nd type of beans.

# %%
df['Class'].value_counts()
# Out:
# Class
# 6    3546
# 5    2636
# 0    2027
# 4    1928
# 3    1630
# 1    1322
# 2     522
# Name: count, dtype: int64

# %% [markdown]
# we can classify data bean 2 only on the basis of its structure itself and outlier characteristics

# %%
matplotlib.rcParams['figure.figsize']=(12,6)
plt.boxplot(df["Solidity"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d274f6cefb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d274f6cf4f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d274f6ced10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d274f6cfa30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d274f653490>],
#  'means': []}

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Class", y ="Solidity", data = df)
# Out:
# <Axes: xlabel='Class', ylabel='Solidity'>

# %%
df['Solidity'].value_counts()
# Out:
# Solidity
# 0.982329    2
# 0.991076    2
# 0.990205    2
# 0.980017    2
# 0.986691    2
#            ..
# 0.987357    1
# 0.980149    1
# 0.990800    1
# 0.989787    1
# 0.989648    1
# Name: count, Length: 13522, dtype: int64

# %%
df.corr()
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966722         0.931834         0.951602
# Perimeter        0.966722   1.000000         0.977338         0.913179
# MajorAxisLength  0.931834   0.977338         1.000000         0.826052
# MinorAxisLength  0.951602   0.913179         0.826052         1.000000
# AspectRation     0.241735   0.385276         0.550335        -0.009161
# Eccentricity     0.267481   0.391066         0.541972         0.019574
# ConvexArea       0.999939   0.967689         0.932607         0.951339
# EquivDiameter    0.984968   0.991380         0.961733         0.948539
# Extent           0.054345  -0.021160        -0.078062         0.145957
# Solidity        -0.196585  -0.303970        -0.284302        -0.155831
# roundness       -0.357530  -0.547647        -0.596358        -0.210344
# Compactness     -0.268067  -0.406857        -0.568377        -0.015066
# ...

# %%
matplotlib.rcParams['figure.figsize']=(12,6)
sns.boxplot(x='Class',y='Area', data=df)
# Out:
# <Axes: xlabel='Class', ylabel='Area'>

# %%
matplotlib.rcParams['figure.figsize']=(12,6)
sns.boxplot(x=df['Class'][0],y='Solidity', data=df)
# Out:
# <Axes: ylabel='Solidity'>

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class  \
# ...

# %% [markdown]
# hypothesis - we have to remove outliers. as of now, there are too many outliers for each beantype. for rectifying that, we need to first encode our features. for that, we have to choose what type of encoding we will be proceeding with

# %%
newdf = df
newdf.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class  \
# ...

# %%
newdf['Area'] = (newdf['Area'] - newdf['Area'].mean()) / newdf['Area'].std()

# %%
sns.boxplot(x=df['Class'][0],y='Area', data=df)
# Out:
# <Axes: ylabel='Area'>

# %%
sns.boxplot(x=newdf['Class'][0],y='Area', data=newdf)
# Out:
# <Axes: ylabel='Area'>

# %%
newdf['Area']
# Out:
# 0       -0.840718
# 1       -0.829157
# 2       -0.807128
# 3       -0.785712
# 4       -0.781210
#            ...
# 13606   -0.373457
# 13607   -0.373320
# 13608   -0.372025
# 13609   -0.371752
# 13610   -0.371343
# Name: Area, Length: 13611, dtype: float64

# %% [markdown]
# this was standardization encoding. no use of this as it does not change the range of variability of data. we have to use different type of encoding.

# %%
df['Area']
# Out:
# 0       -0.840718
# 1       -0.829157
# 2       -0.807128
# 3       -0.785712
# 4       -0.781210
#            ...
# 13606   -0.373457
# 13607   -0.373320
# 13608   -0.372025
# 13609   -0.371752
# 13610   -0.371343
# Name: Area, Length: 13611, dtype: float64

# %% [markdown]
# #pre-processing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/Dry_Bean.csv")

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
dfnew = df.copy()
#for training model without standard scaler
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(dfnew['Class'])
dfnew['Class'] = le.transform(dfnew['Class'])
le.fit(df['Class'])
df['Class'] = le.transform(df['Class'])
#label encoding on both copies
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 3    3546
# 6    2636
# 5    2027
# 4    1928
# 2    1630
# 0    1322
# 1     522
# Name: count, dtype: int64

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x="Class", y ="Area", data = df)
#to check how classes are encoded as compared to previous manual encoding
# Out:
# <Axes: xlabel='Class', ylabel='Area'>

# %%
#standard scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df.iloc[:,:-1]= scaler.fit_transform(df.iloc[:,:-1])
#scaled everything except target class
df.head()
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0 -0.840749  -1.143319        -1.306598        -0.631153     -1.565053
# 1 -0.829188  -1.013924        -1.395911        -0.434445     -1.969784
# 2 -0.807157  -1.078829        -1.252357        -0.585735     -1.514291
# 3 -0.785741  -0.977215        -1.278825        -0.439290     -1.741618
# 4 -0.781239  -1.097384        -1.380471        -0.266663     -2.117993
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0     -2.185720   -0.841451      -1.063341  0.289087  0.367614   1.423867
# 1     -3.686040   -0.826102      -1.044217  0.697477 -0.462907   0.231054
# 2     -2.045336   -0.808704      -1.008084  0.578195  0.518417   1.252865
# 3     -2.742211   -0.773975      -0.973337  0.671260 -2.241767   0.515049
# 4     -4.535028   -0.784286      -0.966080  0.476020  0.804772   1.874992
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %% [markdown]
# #With Standard Scaling, SVM

# %%
x = df.iloc[:,:-1]
y = df['Class']
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn import svm
clf = svm.SVC(kernel='linear')
#linear kernel
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
#predicted on test value after training
accu = clf.score(x_test,y_test)
accu
#accuracy of model
# Out:
# 0.9283878075651855

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
#confusion matrix
disp.plot()
plt.show()

# %%
#precision recall
from sklearn.metrics import precision_recall_fscore_support
#precision-recall-f1-support against test data:
print("precision-recall-f1-support against test data:",precision_recall_fscore_support(y_test,y_pred,average = 'macro'))
# Out:
# precision-recall-f1-support against test data: (0.9404875015255438, 0.9390414807782632, 0.9397184763513893, None)

# %%
#classification report
from sklearn.metrics import classification_report
tar_name = df['Class']
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92       261
#            1       1.00      1.00      1.00       117
#            2       0.94      0.94      0.94       317
#            3       0.91      0.91      0.91       671
#            4       0.97      0.97      0.97       408
#            5       0.97      0.94      0.96       413
#            6       0.87      0.89      0.88       536
#
#     accuracy                           0.93      2723
#    macro avg       0.94      0.94      0.94      2723
# weighted avg       0.93      0.93      0.93      2723

# %%
df.head()
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0 -0.840749  -1.143319        -1.306598        -0.631153     -1.565053
# 1 -0.829188  -1.013924        -1.395911        -0.434445     -1.969784
# 2 -0.807157  -1.078829        -1.252357        -0.585735     -1.514291
# 3 -0.785741  -0.977215        -1.278825        -0.439290     -1.741618
# 4 -0.781239  -1.097384        -1.380471        -0.266663     -2.117993
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0     -2.185720   -0.841451      -1.063341  0.289087  0.367614   1.423867
# 1     -3.686040   -0.826102      -1.044217  0.697477 -0.462907   0.231054
# 2     -2.045336   -0.808704      -1.008084  0.578195  0.518417   1.252865
# 3     -2.742211   -0.773975      -0.973337  0.671260 -2.241767   0.515049
# 4     -4.535028   -0.784286      -0.966080  0.476020  0.804772   1.874992
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %% [markdown]
# #SVM without Standard Scaling

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
dfnew = pd.read_csv("/content/Dry_Bean.csv")
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(dfnew['Class'])
dfnew['Class'] = le.transform(dfnew['Class'])
x = dfnew.iloc[:,:-1]
y = dfnew['Class']
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn import svm
clf = svm.SVC(kernel='linear')
#linear kernel
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
#predicted on test value after training
accu = clf.score(x_test,y_test)
accu
#accuracy of model
# Out:
# 0.9173705471905986

# %% [markdown]
# #Conclusion: via svm-
# ##accuracy with standardization =
# ##0.9283878075651855
#
# ##accuracy without standardization =
# ##0.9173705471905986
#
# ###no major difference with standardization in this dataset

# %%
#error rate
from sklearn.metrics import accuracy_score
err = 1-accuracy_score(y_test,y_pred)
print("error rate: ", err)
# Out:
# error rate:  0.08262945280940137

# %% [markdown]
# #KNN Classification

# %%
##without standardization
x = dfnew.iloc[:,:-1]
y = dfnew['Class']
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
#predicted value
#now checking accuracy
from sklearn.metrics import accuracy_score
accu = accuracy_score(y_test,y_pred)
print(accu)
# Out:
# 0.7271391847227323

# %%
##with standardization
x = df.iloc[:,:-1]
y = df['Class']
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
#predicted value
#now checking accuracy
from sklearn.metrics import accuracy_score
accu = accuracy_score(y_test,y_pred)
print(accu)
# Out:
# 0.9258171134777818

# %%
print(type(x_test))
print(type(y_test))
print(type(y_pred))
x_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>
#            Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 1488  -0.365218  -0.532278        -0.699519         0.111983     -1.330113
# 2611   0.518320   1.089549         0.586132         0.791512     -0.106143
# 749   -0.518101  -0.683994        -0.836862        -0.175910     -1.236665
# 99    -0.678828  -0.965544        -1.139157        -0.278714     -1.663886
# 11298 -0.788571  -0.969347        -0.961919        -0.917663     -0.432975
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 1488      -1.592944   -0.372549      -0.352918  0.437396  1.064426   1.597939
# 2611       0.169698    0.550947       0.704943  0.365695 -3.127637  -2.516723
# 749       -1.391983   -0.521807      -0.566452 -0.103759  0.648568   1.240429
# 99        -2.482813   -0.684870      -0.805076  0.412487  1.254524   1.972582
# ...

# %% [markdown]
# #Conclusion: Via KNN:-
#
# ##without standardization -
# ##0.7271391847227323
#
# ##with standardization -
# ##0.9258171134777818

# %%
yprednew = pd.Series(y_pred, index=x_test.index, name='ypred')
dfnew = pd.concat([x_test, y_test.rename('ytest'), yprednew], axis=1)
dfnew.reset_index(drop=True, inplace = True)
dfnew.head()
dfnew.to_csv('report.csv', header=True, index = True)

# %% [markdown]
# ##end
